# %%
# import python libs
import pandas as pd
import numpy as np

# %%
# define the database connection string

# host is the bridge gateway of dbnet
DB_HOST = '192.168.0.1' 
DB_PORT = '5432'
DB_DBNAME = 'bank_db'
DB_USERNAME = 'bank_user' 
DB_PASSWORD = 'bank_pw' 
db_str = 'postgresql://{username}:{password}@{host}:{port}/{dbname}'.format(username=DB_USERNAME,password=DB_PASSWORD,host=DB_HOST,port=DB_PORT,dbname=DB_DBNAME)
print(db_str)
# Out:
# postgresql://bank_user:bank_pw@192.168.0.1:5432/bank_db

# %%
# use plain SQL to query database

# load dependency
# %load_ext sql
# set the connection string
# %sql $db_str
# Out:
# 'Connected: bank_user@bank_db'

# %%
# extract info about tables in database bank_db
# %sql SELECT * FROM pg_catalog.pg_tables WHERE schemaname = 'public'
# %sql SELECT * FROM information_schema.tables WHERE table_type = 'BASE TABLE' AND table_schema = 'public' ORDER BY table_type, table_name
# Out:
#  * postgresql://bank_user:***@192.168.0.1:5432/bank_db
# 8 rows affected.
# [('bank_db', 'public', 'account', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'card', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'client', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'disp', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'district', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'loan', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'orders', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('bank_db', 'public', 'trans', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# extract info about table account
# %sql SELECT * FROM INFORMATION_SCHEMA.COLUMNS where table_name = 'account'
# Out:
#  * postgresql://bank_user:***@192.168.0.1:5432/bank_db
# 4 rows affected.
# [('bank_db', 'public', 'account', 'account_id', 1, None, 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'bank_db', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('bank_db', 'public', 'account', 'district_id', 2, None, 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'bank_db', 'pg_catalog', 'int4', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('bank_db', 'public', 'account', 'date', 3, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None, None, None, 'bank_db', 'pg_catalog', 'date', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('bank_db', 'public', 'account', 'frequency', 4, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'bank_db', 'pg_catalog', 'text', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %%
# query database's table account
accounts = %sql SELECT * FROM account
# access accounts by index
print('Default selection: '+ str(accounts[576]))
# access accounts as pandas DataFrame by index
print('DataFrame based selection: '+ str(accounts.DataFrame().iloc[576]))
# Out:
#  * postgresql://bank_user:***@192.168.0.1:5432/bank_db
# 4500 rows affected.
# Default selection: (8027, 44, datetime.date(1993, 7, 7), 'POPLATEK TYDNE')
# DataFrame based selection: account_id               8027
# district_id                44
# date               1993-07-07
# frequency      POPLATEK TYDNE
# Name: 576, dtype: object

# %%
# Use Pandas sql and store query results in pandas DataFrame
import pandas.io.sql as sql
import sqlalchemy

# create connection to database
engine = sqlalchemy.create_engine(db_str)
# query database's table account
accounts = sql.read_sql("SELECT * FROM account", engine)
print('DataFrame based selection: '+ str(accounts.iloc[576]))
# set index to account_id (as in the database)
accounts.set_index('account_id', inplace=True)
print('DataFrame based selection: '+ str(accounts.iloc[576]))
# print result
accounts
# Out:
# DataFrame based selection: account_id               8027
# district_id                44
# date               1993-07-07
# frequency      POPLATEK TYDNE
# Name: 576, dtype: object
# DataFrame based selection: district_id                44
# date               1993-07-07
# frequency      POPLATEK TYDNE
# Name: 8027, dtype: object
#             district_id        date           frequency
# account_id
# 576                  55  1993-01-01    POPLATEK MESICNE
# 3818                 74  1993-01-01    POPLATEK MESICNE
# 704                  55  1993-01-01    POPLATEK MESICNE
# 2378                 16  1993-01-01    POPLATEK MESICNE
# 2632                 24  1993-01-02    POPLATEK MESICNE
# 1972                 77  1993-01-02    POPLATEK MESICNE
# 1539                  1  1993-01-03  POPLATEK PO OBRATU
# 793                  47  1993-01-03    POPLATEK MESICNE
# 2484                 74  1993-01-03    POPLATEK MESICNE
# 1695                 76  1993-01-03    POPLATEK MESICNE
# 1726                 48  1993-01-03    POPLATEK MESICNE
# 2881                 70  1993-01-04    POPLATEK MESICNE
# 2357                 19  1993-01-04    POPLATEK MESICNE
# 2177                 62  1993-01-04    POPLATEK MESICNE
# 485                   6  1993-01-04  POPLATEK PO OBRATU
# 652                  21  1993-01-05    POPLATEK MESICNE
# 9635                 70  1993-01-05    POPLATEK MESICNE
# 1844                 44  1993-01-06    POPLATEK MESICNE
# 1926                 37  1993-01-06    POPLATEK MESICNE
# 2393                 10  1993-01-07    POPLATEK MESICNE
# 3510                 41  1993-01-07    POPLATEK MESICNE
# 1276                 36  1993-01-07    POPLATEK MESICNE
# 1637                  1  1993-01-08    POPLATEK MESICNE
# 3871                 26  1993-01-08    POPLATEK MESICNE
# 192                  55  1993-01-08    POPLATEK MESICNE
# 764                   1  1993-01-08    POPLATEK MESICNE
# 2087                  7  1993-01-08      POPLATEK TYDNE
# 2122                 68  1993-01-08    POPLATEK MESICNE
# 3592                 54  1993-01-08    POPLATEK MESICNE
# 3487                 41  1993-01-08    POPLATEK MESICNE
# ...                 ...         ...                 ...
# 579                   1  1997-12-16    POPLATEK MESICNE
# 2892                 64  1997-12-16    POPLATEK MESICNE
# 1186                 64  1997-12-17    POPLATEK MESICNE
# 2440                 19  1997-12-18    POPLATEK MESICNE
# 2791                 25  1997-12-19    POPLATEK MESICNE
# 3169                 19  1997-12-19    POPLATEK MESICNE
# 2049                 67  1997-12-19    POPLATEK MESICNE
# 758                  51  1997-12-19    POPLATEK MESICNE
# 1177                 27  1997-12-20    POPLATEK MESICNE
# 246                  65  1997-12-20    POPLATEK MESICNE
# 1171                 18  1997-12-20    POPLATEK MESICNE
# 3187                 59  1997-12-20    POPLATEK MESICNE
# 3385                  1  1997-12-21    POPLATEK MESICNE
# 703                  54  1997-12-21    POPLATEK MESICNE
# 1318                 56  1997-12-22    POPLATEK MESICNE
# 889                  43  1997-12-22    POPLATEK MESICNE
# 4332                 74  1997-12-23    POPLATEK MESICNE
# 564                   5  1997-12-23    POPLATEK MESICNE
# 3934                  6  1997-12-23    POPLATEK MESICNE
# 1983                 54  1997-12-25    POPLATEK MESICNE
# 727                  35  1997-12-25    POPLATEK MESICNE
# 3048                 74  1997-12-26      POPLATEK TYDNE
# 3025                 25  1997-12-27    POPLATEK MESICNE
# 906                  59  1997-12-27    POPLATEK MESICNE
# 845                  14  1997-12-27    POPLATEK MESICNE
# 124                  55  1997-12-28    POPLATEK MESICNE
# 3958                 59  1997-12-28    POPLATEK MESICNE
# 777                  30  1997-12-28    POPLATEK MESICNE
# 1573                 63  1997-12-29    POPLATEK MESICNE
# 3276                  1  1997-12-29    POPLATEK MESICNE
#
# [4500 rows x 3 columns]

# %%
# use postgres adapter to query database 

# install postgres dependency
import psycopg2 as pg

# create connection
connection = pg.connect(db_str)
cursor = connection.cursor()

# query database's table account
query = "SELECT * FROM account"
cursor.execute(query)

# print query result
accounts = cursor.fetchall() 
for row in accounts:
    print("account_id = ", row[0], )
    print("district_id = ", row[1])
    print("date = ", row[2])
    print("frequency  = ", row[3], "\n")
    
# close communication with the PostgreSQL database server
cursor.close()
# close the connection
connection.close()
# Out:
# account_id =  576
# district_id =  55
# date =  1993-01-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  3818
# district_id =  74
# date =  1993-01-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  704
# district_id =  55
# date =  1993-01-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  2378
# district_id =  16
# date =  1993-01-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  2632
# district_id =  24
# date =  1993-01-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1972
# district_id =  77
# date =  1993-01-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1539
# district_id =  1
# date =  1993-01-03
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  793
# district_id =  47
# date =  1993-01-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  2484
# district_id =  74
# date =  1993-01-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1695
# district_id =  76
# date =  1993-01-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1726
# district_id =  48
# date =  1993-01-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  2881
# district_id =  70
# date =  1993-01-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  2357
# district_id =  19
# date =  1993-01-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  2177
# district_id =  62
# date =  1993-01-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  485
# district_id =  6
# date =  1993-01-04
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  652
# district_id =  21
# date =  1993-01-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  9635
# district_id =  70
# date =  1993-01-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  1844
# district_id =  44
# date =  1993-01-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  1926
# district_id =  37
# date =  1993-01-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2393
# district_id =  10
# date =  1993-01-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  3510
# district_id =  41
# date =  1993-01-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1276
# district_id =  36
# date =  1993-01-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1637
# district_id =  1
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3871
# district_id =  26
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  192
# district_id =  55
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  764
# district_id =  1
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2087
# district_id =  7
# date =  1993-01-08
# frequency  =  POPLATEK TYDNE
#
# account_id =  2122
# district_id =  68
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3592
# district_id =  54
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3487
# district_id =  41
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  435
# district_id =  38
# date =  1993-01-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1730
# district_id =  1
# date =  1993-01-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1493
# district_id =  41
# date =  1993-01-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  374
# district_id =  38
# date =  1993-01-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2925
# district_id =  1
# date =  1993-01-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  866
# district_id =  9
# date =  1993-01-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1628
# district_id =  60
# date =  1993-01-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2379
# district_id =  44
# date =  1993-01-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1979
# district_id =  26
# date =  1993-01-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  346
# district_id =  37
# date =  1993-01-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1338
# district_id =  74
# date =  1993-01-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1909
# district_id =  14
# date =  1993-01-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2099
# district_id =  3
# date =  1993-01-12
# frequency  =  POPLATEK TYDNE
#
# account_id =  3760
# district_id =  44
# date =  1993-01-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  5270
# district_id =  44
# date =  1993-01-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  1699
# district_id =  53
# date =  1993-01-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  3909
# district_id =  1
# date =  1993-01-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2926
# district_id =  50
# date =  1993-01-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  1731
# district_id =  33
# date =  1993-01-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  11265
# district_id =  15
# date =  1993-01-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2519
# district_id =  4
# date =  1993-01-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  10364
# district_id =  55
# date =  1993-01-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  1481
# district_id =  15
# date =  1993-01-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  401
# district_id =  32
# date =  1993-01-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  4034
# district_id =  1
# date =  1993-01-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2330
# district_id =  54
# date =  1993-01-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1806
# district_id =  40
# date =  1993-01-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3834
# district_id =  54
# date =  1993-01-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1222
# district_id =  66
# date =  1993-01-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  212
# district_id =  27
# date =  1993-01-20
# frequency  =  POPLATEK TYDNE
#
# account_id =  456
# district_id =  49
# date =  1993-01-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  459
# district_id =  47
# date =  1993-01-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  772
# district_id =  45
# date =  1993-01-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1019
# district_id =  52
# date =  1993-01-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  11295
# district_id =  74
# date =  1993-01-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  2970
# district_id =  60
# date =  1993-01-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2676
# district_id =  73
# date =  1993-01-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1536
# district_id =  41
# date =  1993-01-22
# frequency  =  POPLATEK TYDNE
#
# account_id =  1179
# district_id =  74
# date =  1993-01-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  280
# district_id =  25
# date =  1993-01-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  2425
# district_id =  41
# date =  1993-01-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  9307
# district_id =  68
# date =  1993-01-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  4055
# district_id =  23
# date =  1993-01-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  5065
# district_id =  66
# date =  1993-01-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  3704
# district_id =  75
# date =  1993-01-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  477
# district_id =  1
# date =  1993-01-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  5891
# district_id =  54
# date =  1993-01-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1000
# district_id =  77
# date =  1993-01-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1750
# district_id =  1
# date =  1993-01-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2023
# district_id =  68
# date =  1993-01-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  6473
# district_id =  12
# date =  1993-01-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  1649
# district_id =  46
# date =  1993-01-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2670
# district_id =  13
# date =  1993-01-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1127
# district_id =  27
# date =  1993-01-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  163
# district_id =  30
# date =  1993-01-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  2566
# district_id =  48
# date =  1993-01-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  9
# district_id =  70
# date =  1993-01-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1144
# district_id =  59
# date =  1993-01-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  2902
# district_id =  32
# date =  1993-01-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  4296
# district_id =  63
# date =  1993-01-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  443
# district_id =  64
# date =  1993-01-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  3693
# district_id =  61
# date =  1993-01-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  2070
# district_id =  72
# date =  1993-01-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  1843
# district_id =  12
# date =  1993-01-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  2714
# district_id =  1
# date =  1993-01-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  4078
# district_id =  40
# date =  1993-01-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  1675
# district_id =  36
# date =  1993-02-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  5868
# district_id =  44
# date =  1993-02-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1805
# district_id =  1
# date =  1993-02-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  2434
# district_id =  17
# date =  1993-02-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  3007
# district_id =  16
# date =  1993-02-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  2574
# district_id =  68
# date =  1993-02-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  862
# district_id =  64
# date =  1993-02-02
# frequency  =  POPLATEK TYDNE
#
# account_id =  1132
# district_id =  1
# date =  1993-02-03
# frequency  =  POPLATEK TYDNE
#
# account_id =  4484
# district_id =  54
# date =  1993-02-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  943
# district_id =  1
# date =  1993-02-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  3514
# district_id =  7
# date =  1993-02-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  3983
# district_id =  67
# date =  1993-02-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  9265
# district_id =  1
# date =  1993-02-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  465
# district_id =  32
# date =  1993-02-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  982
# district_id =  54
# date =  1993-02-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  411
# district_id =  70
# date =  1993-02-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  890
# district_id =  14
# date =  1993-02-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  627
# district_id =  63
# date =  1993-02-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  2429
# district_id =  61
# date =  1993-02-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  3960
# district_id =  64
# date =  1993-02-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2256
# district_id =  48
# date =  1993-02-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  8051
# district_id =  1
# date =  1993-02-07
# frequency  =  POPLATEK TYDNE
#
# account_id =  2647
# district_id =  73
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2241
# district_id =  6
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  5622
# district_id =  70
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2884
# district_id =  1
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1830
# district_id =  10
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  7753
# district_id =  74
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  244
# district_id =  24
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1477
# district_id =  1
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  4240
# district_id =  50
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1006
# district_id =  6
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  830
# district_id =  74
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  9188
# district_id =  45
# date =  1993-02-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1965
# district_id =  57
# date =  1993-02-08
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  1134
# district_id =  6
# date =  1993-02-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1601
# district_id =  10
# date =  1993-02-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2861
# district_id =  38
# date =  1993-02-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  813
# district_id =  16
# date =  1993-02-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2585
# district_id =  75
# date =  1993-02-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2220
# district_id =  16
# date =  1993-02-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2763
# district_id =  64
# date =  1993-02-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2342
# district_id =  51
# date =  1993-02-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1944
# district_id =  72
# date =  1993-02-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  1966
# district_id =  27
# date =  1993-02-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  1801
# district_id =  46
# date =  1993-02-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  2543
# district_id =  68
# date =  1993-02-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  2293
# district_id =  31
# date =  1993-02-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  11013
# district_id =  1
# date =  1993-02-14
# frequency  =  POPLATEK TYDNE
#
# account_id =  2423
# district_id =  30
# date =  1993-02-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  142
# district_id =  51
# date =  1993-02-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  3424
# district_id =  74
# date =  1993-02-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  539
# district_id =  13
# date =  1993-02-16
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  979
# district_id =  21
# date =  1993-02-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3554
# district_id =  66
# date =  1993-02-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3545
# district_id =  51
# date =  1993-02-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  3047
# district_id =  16
# date =  1993-02-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  3374
# district_id =  21
# date =  1993-02-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  96
# district_id =  68
# date =  1993-02-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  461
# district_id =  30
# date =  1993-02-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  3593
# district_id =  1
# date =  1993-02-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  3026
# district_id =  24
# date =  1993-02-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  1054
# district_id =  10
# date =  1993-02-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  2433
# district_id =  71
# date =  1993-02-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3691
# district_id =  50
# date =  1993-02-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3787
# district_id =  70
# date =  1993-02-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  128
# district_id =  2
# date =  1993-02-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3168
# district_id =  39
# date =  1993-02-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  4937
# district_id =  12
# date =  1993-02-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  2124
# district_id =  69
# date =  1993-02-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  322
# district_id =  1
# date =  1993-02-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  4355
# district_id =  31
# date =  1993-02-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1678
# district_id =  1
# date =  1993-02-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2396
# district_id =  2
# date =  1993-02-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1005
# district_id =  54
# date =  1993-02-23
# frequency  =  POPLATEK TYDNE
#
# account_id =  697
# district_id =  28
# date =  1993-02-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  925
# district_id =  59
# date =  1993-02-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  2110
# district_id =  64
# date =  1993-02-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1366
# district_id =  60
# date =  1993-02-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  1050
# district_id =  57
# date =  1993-02-24
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  3117
# district_id =  33
# date =  1993-02-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  562
# district_id =  50
# date =  1993-02-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  5369
# district_id =  54
# date =  1993-02-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  2242
# district_id =  7
# date =  1993-02-25
# frequency  =  POPLATEK TYDNE
#
# account_id =  197
# district_id =  1
# date =  1993-02-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  496
# district_id =  69
# date =  1993-02-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2
# district_id =  1
# date =  1993-02-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  7401
# district_id =  1
# date =  1993-02-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2486
# district_id =  1
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  428
# district_id =  1
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3651
# district_id =  23
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1775
# district_id =  17
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1688
# district_id =  70
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  361
# district_id =  51
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1829
# district_id =  43
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1575
# district_id =  1
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  9203
# district_id =  70
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3008
# district_id =  72
# date =  1993-02-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  239
# district_id =  69
# date =  1993-03-01
# frequency  =  POPLATEK TYDNE
#
# account_id =  3302
# district_id =  21
# date =  1993-03-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  415
# district_id =  25
# date =  1993-03-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  3513
# district_id =  20
# date =  1993-03-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  4134
# district_id =  7
# date =  1993-03-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1077
# district_id =  14
# date =  1993-03-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1713
# district_id =  43
# date =  1993-03-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1378
# district_id =  59
# date =  1993-03-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  2503
# district_id =  1
# date =  1993-03-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  559
# district_id =  46
# date =  1993-03-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  6555
# district_id =  38
# date =  1993-03-05
# frequency  =  POPLATEK TYDNE
#
# account_id =  744
# district_id =  42
# date =  1993-03-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  882
# district_id =  9
# date =  1993-03-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  86
# district_id =  54
# date =  1993-03-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1126
# district_id =  56
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2666
# district_id =  49
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  944
# district_id =  70
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1545
# district_id =  1
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2453
# district_id =  1
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3734
# district_id =  43
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3935
# district_id =  23
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  396
# district_id =  21
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2694
# district_id =  7
# date =  1993-03-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  4596
# district_id =  74
# date =  1993-03-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2489
# district_id =  72
# date =  1993-03-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2895
# district_id =  19
# date =  1993-03-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  317
# district_id =  76
# date =  1993-03-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2555
# district_id =  53
# date =  1993-03-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  494
# district_id =  60
# date =  1993-03-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2219
# district_id =  60
# date =  1993-03-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2581
# district_id =  72
# date =  1993-03-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  112
# district_id =  6
# date =  1993-03-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  3674
# district_id =  38
# date =  1993-03-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2039
# district_id =  44
# date =  1993-03-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2712
# district_id =  9
# date =  1993-03-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  395
# district_id =  1
# date =  1993-03-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2974
# district_id =  9
# date =  1993-03-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  123
# district_id =  21
# date =  1993-03-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  9640
# district_id =  1
# date =  1993-03-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  3108
# district_id =  53
# date =  1993-03-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2508
# district_id =  34
# date =  1993-03-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2458
# district_id =  40
# date =  1993-03-14
# frequency  =  POPLATEK TYDNE
#
# account_id =  588
# district_id =  66
# date =  1993-03-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  7231
# district_id =  10
# date =  1993-03-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  6701
# district_id =  49
# date =  1993-03-15
# frequency  =  POPLATEK TYDNE
#
# account_id =  3883
# district_id =  72
# date =  1993-03-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  222
# district_id =  37
# date =  1993-03-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  2497
# district_id =  65
# date =  1993-03-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  1372
# district_id =  1
# date =  1993-03-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3835
# district_id =  50
# date =  1993-03-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  7445
# district_id =  64
# date =  1993-03-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2527
# district_id =  38
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  425
# district_id =  9
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  860
# district_id =  1
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  6034
# district_id =  6
# date =  1993-03-19
# frequency  =  POPLATEK TYDNE
#
# account_id =  11065
# district_id =  11
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  9883
# district_id =  1
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  115
# district_id =  68
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1189
# district_id =  59
# date =  1993-03-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3675
# district_id =  64
# date =  1993-03-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3069
# district_id =  66
# date =  1993-03-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  2762
# district_id =  19
# date =  1993-03-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  892
# district_id =  70
# date =  1993-03-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  1535
# district_id =  46
# date =  1993-03-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  2618
# district_id =  60
# date =  1993-03-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  2651
# district_id =  2
# date =  1993-03-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  5442
# district_id =  34
# date =  1993-03-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1787
# district_id =  30
# date =  1993-03-22
# frequency  =  POPLATEK TYDNE
#
# account_id =  1397
# district_id =  17
# date =  1993-03-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  3785
# district_id =  10
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  623
# district_id =  1
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  8260
# district_id =  31
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  3678
# district_id =  1
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  3001
# district_id =  1
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  655
# district_id =  53
# date =  1993-03-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  4093
# district_id =  1
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  3260
# district_id =  68
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  2528
# district_id =  65
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  2011
# district_id =  75
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1721
# district_id =  68
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1332
# district_id =  59
# date =  1993-03-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1402
# district_id =  74
# date =  1993-03-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  3283
# district_id =  68
# date =  1993-03-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  3781
# district_id =  31
# date =  1993-03-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  7203
# district_id =  71
# date =  1993-03-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  1065
# district_id =  72
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3076
# district_id =  54
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  4347
# district_id =  1
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1157
# district_id =  7
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  9403
# district_id =  1
# date =  1993-03-27
# frequency  =  POPLATEK TYDNE
#
# account_id =  1874
# district_id =  9
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1115
# district_id =  34
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3586
# district_id =  59
# date =  1993-03-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  62
# district_id =  47
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  1771
# district_id =  69
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  5483
# district_id =  13
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  8330
# district_id =  48
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  187
# district_id =  5
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  423
# district_id =  12
# date =  1993-03-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  6425
# district_id =  31
# date =  1993-03-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  2493
# district_id =  62
# date =  1993-03-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  2896
# district_id =  29
# date =  1993-03-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  2245
# district_id =  29
# date =  1993-03-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  3923
# district_id =  52
# date =  1993-03-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  1898
# district_id =  70
# date =  1993-04-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  3367
# district_id =  1
# date =  1993-04-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  3391
# district_id =  74
# date =  1993-04-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  8519
# district_id =  23
# date =  1993-04-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1780
# district_id =  1
# date =  1993-04-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  3915
# district_id =  65
# date =  1993-04-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  3980
# district_id =  75
# date =  1993-04-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  4350
# district_id =  63
# date =  1993-04-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  686
# district_id =  41
# date =  1993-04-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  362
# district_id =  15
# date =  1993-04-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  299
# district_id =  77
# date =  1993-04-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  2488
# district_id =  5
# date =  1993-04-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2985
# district_id =  71
# date =  1993-04-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  385
# district_id =  5
# date =  1993-04-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  2817
# district_id =  56
# date =  1993-04-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  2056
# district_id =  58
# date =  1993-04-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  2002
# district_id =  1
# date =  1993-04-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  748
# district_id =  10
# date =  1993-04-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  220
# district_id =  72
# date =  1993-04-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1422
# district_id =  68
# date =  1993-04-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1147
# district_id =  44
# date =  1993-04-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  3788
# district_id =  70
# date =  1993-04-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1891
# district_id =  32
# date =  1993-04-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1239
# district_id =  1
# date =  1993-04-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  8321
# district_id =  77
# date =  1993-04-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  3213
# district_id =  51
# date =  1993-04-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2838
# district_id =  3
# date =  1993-04-13
# frequency  =  POPLATEK TYDNE
#
# account_id =  3644
# district_id =  38
# date =  1993-04-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  4318
# district_id =  33
# date =  1993-04-13
# frequency  =  POPLATEK TYDNE
#
# account_id =  2648
# district_id =  51
# date =  1993-04-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  2313
# district_id =  26
# date =  1993-04-13
# frequency  =  POPLATEK TYDNE
#
# account_id =  5428
# district_id =  24
# date =  1993-04-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  7123
# district_id =  64
# date =  1993-04-14
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  279
# district_id =  39
# date =  1993-04-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  104
# district_id =  37
# date =  1993-04-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  497
# district_id =  55
# date =  1993-04-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  1152
# district_id =  45
# date =  1993-04-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  83
# district_id =  26
# date =  1993-04-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  2008
# district_id =  52
# date =  1993-04-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3327
# district_id =  45
# date =  1993-04-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  5740
# district_id =  43
# date =  1993-04-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  8132
# district_id =  5
# date =  1993-04-17
# frequency  =  POPLATEK TYDNE
#
# account_id =  10738
# district_id =  45
# date =  1993-04-17
# frequency  =  POPLATEK TYDNE
#
# account_id =  2216
# district_id =  74
# date =  1993-04-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  1815
# district_id =  66
# date =  1993-04-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  2823
# district_id =  57
# date =  1993-04-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  4321
# district_id =  47
# date =  1993-04-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  1773
# district_id =  33
# date =  1993-04-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  7454
# district_id =  4
# date =  1993-04-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  188
# district_id =  54
# date =  1993-04-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  10973
# district_id =  18
# date =  1993-04-20
# frequency  =  POPLATEK TYDNE
#
# account_id =  2599
# district_id =  48
# date =  1993-04-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  1166
# district_id =  11
# date =  1993-04-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  504
# district_id =  73
# date =  1993-04-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1518
# district_id =  67
# date =  1993-04-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  2189
# district_id =  75
# date =  1993-04-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  6040
# district_id =  1
# date =  1993-04-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2876
# district_id =  52
# date =  1993-04-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1505
# district_id =  69
# date =  1993-04-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  6897
# district_id =  48
# date =  1993-04-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  4377
# district_id =  28
# date =  1993-04-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  717
# district_id =  75
# date =  1993-04-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  9707
# district_id =  70
# date =  1993-04-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  2814
# district_id =  72
# date =  1993-04-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  3068
# district_id =  59
# date =  1993-04-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1476
# district_id =  61
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  897
# district_id =  38
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  977
# district_id =  1
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2639
# district_id =  17
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  1032
# district_id =  11
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  928
# district_id =  20
# date =  1993-04-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  168
# district_id =  31
# date =  1993-04-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  2175
# district_id =  1
# date =  1993-04-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  10105
# district_id =  55
# date =  1993-04-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  1392
# district_id =  60
# date =  1993-04-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  3697
# district_id =  45
# date =  1993-04-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  5313
# district_id =  40
# date =  1993-04-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  2222
# district_id =  47
# date =  1993-05-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  2641
# district_id =  7
# date =  1993-05-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  5423
# district_id =  15
# date =  1993-05-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  2609
# district_id =  73
# date =  1993-05-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  5472
# district_id =  1
# date =  1993-05-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  2932
# district_id =  72
# date =  1993-05-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  4254
# district_id =  70
# date =  1993-05-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  3965
# district_id =  31
# date =  1993-05-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  10656
# district_id =  8
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  887
# district_id =  1
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  4743
# district_id =  64
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  1048
# district_id =  35
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  1671
# district_id =  6
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  1236
# district_id =  19
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  1822
# district_id =  30
# date =  1993-05-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  3316
# district_id =  28
# date =  1993-05-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2037
# district_id =  20
# date =  1993-05-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  10079
# district_id =  62
# date =  1993-05-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  3999
# district_id =  35
# date =  1993-05-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  551
# district_id =  77
# date =  1993-05-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1200
# district_id =  33
# date =  1993-05-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1161
# district_id =  66
# date =  1993-05-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  5372
# district_id =  48
# date =  1993-05-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3050
# district_id =  60
# date =  1993-05-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1784
# district_id =  59
# date =  1993-05-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1603
# district_id =  1
# date =  1993-05-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1887
# district_id =  68
# date =  1993-05-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1644
# district_id =  1
# date =  1993-05-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1658
# district_id =  73
# date =  1993-05-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  44
# district_id =  32
# date =  1993-05-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1039
# district_id =  70
# date =  1993-05-10
# frequency  =  POPLATEK TYDNE
#
# account_id =  1071
# district_id =  68
# date =  1993-05-10
# frequency  =  POPLATEK TYDNE
#
# account_id =  2410
# district_id =  54
# date =  1993-05-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2523
# district_id =  10
# date =  1993-05-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  790
# district_id =  54
# date =  1993-05-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2583
# district_id =  62
# date =  1993-05-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1782
# district_id =  8
# date =  1993-05-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  751
# district_id =  3
# date =  1993-05-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2061
# district_id =  24
# date =  1993-05-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  8261
# district_id =  13
# date =  1993-05-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2321
# district_id =  35
# date =  1993-05-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  1334
# district_id =  74
# date =  1993-05-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  3649
# district_id =  54
# date =  1993-05-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  555
# district_id =  24
# date =  1993-05-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  3173
# district_id =  39
# date =  1993-05-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  863
# district_id =  71
# date =  1993-05-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3181
# district_id =  42
# date =  1993-05-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3210
# district_id =  1
# date =  1993-05-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  489
# district_id =  16
# date =  1993-05-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  947
# district_id =  59
# date =  1993-05-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  3284
# district_id =  64
# date =  1993-05-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  1610
# district_id =  52
# date =  1993-05-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  4225
# district_id =  55
# date =  1993-05-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  1412
# district_id =  64
# date =  1993-05-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  1937
# district_id =  36
# date =  1993-05-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  991
# district_id =  39
# date =  1993-05-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  1180
# district_id =  20
# date =  1993-05-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  2758
# district_id =  70
# date =  1993-05-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  2711
# district_id =  58
# date =  1993-05-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1652
# district_id =  74
# date =  1993-05-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3099
# district_id =  70
# date =  1993-05-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  11111
# district_id =  1
# date =  1993-05-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  9591
# district_id =  74
# date =  1993-05-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  9828
# district_id =  11
# date =  1993-05-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  5385
# district_id =  44
# date =  1993-05-21
# frequency  =  POPLATEK TYDNE
#
# account_id =  23
# district_id =  30
# date =  1993-05-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2645
# district_id =  54
# date =  1993-05-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2991
# district_id =  19
# date =  1993-05-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  3469
# district_id =  76
# date =  1993-05-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1851
# district_id =  55
# date =  1993-05-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  3844
# district_id =  67
# date =  1993-05-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1442
# district_id =  23
# date =  1993-05-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  3064
# district_id =  40
# date =  1993-05-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  3558
# district_id =  4
# date =  1993-05-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1534
# district_id =  1
# date =  1993-05-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  334
# district_id =  1
# date =  1993-05-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  1786
# district_id =  1
# date =  1993-05-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  1272
# district_id =  40
# date =  1993-05-25
# frequency  =  POPLATEK TYDNE
#
# account_id =  2436
# district_id =  67
# date =  1993-05-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  3796
# district_id =  53
# date =  1993-05-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  119
# district_id =  27
# date =  1993-05-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  3063
# district_id =  72
# date =  1993-05-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  18
# district_id =  43
# date =  1993-05-26
# frequency  =  POPLATEK TYDNE
#
# account_id =  11320
# district_id =  44
# date =  1993-05-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  3888
# district_id =  39
# date =  1993-05-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1584
# district_id =  30
# date =  1993-05-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  5546
# district_id =  43
# date =  1993-05-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  2029
# district_id =  55
# date =  1993-05-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  10911
# district_id =  1
# date =  1993-05-29
# frequency  =  POPLATEK TYDNE
#
# account_id =  2467
# district_id =  33
# date =  1993-05-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  2962
# district_id =  1
# date =  1993-05-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  165
# district_id =  25
# date =  1993-06-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  1617
# district_id =  45
# date =  1993-06-01
# frequency  =  POPLATEK MESICNE
#
# account_id =  327
# district_id =  54
# date =  1993-06-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  2068
# district_id =  21
# date =  1993-06-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  4448
# district_id =  60
# date =  1993-06-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  640
# district_id =  32
# date =  1993-06-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  510
# district_id =  1
# date =  1993-06-02
# frequency  =  POPLATEK TYDNE
#
# account_id =  2534
# district_id =  61
# date =  1993-06-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  1018
# district_id =  7
# date =  1993-06-03
# frequency  =  POPLATEK MESICNE
# account_id =  1285
# district_id =  65
# date =  1993-06-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  3670
# district_id =  27
# date =  1993-06-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  1743
# district_id =  51
# date =  1993-06-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  3072
# district_id =  8
# date =  1993-06-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  2146
# district_id =  31
# date =  1993-06-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  4576
# district_id =  27
# date =  1993-06-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  3258
# district_id =  53
# date =  1993-06-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  2176
# district_id =  67
# date =  1993-06-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  8934
# district_id =  51
# date =  1993-06-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  1999
# district_id =  70
# date =  1993-06-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2741
# district_id =  15
# date =  1993-06-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  4427
# district_id =  32
# date =  1993-06-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  3682
# district_id =  70
# date =  1993-06-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  2862
# district_id =  33
# date =  1993-06-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  3032
# district_id =  5
# date =  1993-06-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  701
# district_id =  69
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  6281
# district_id =  56
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  306
# district_id =  16
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1207
# district_id =  67
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1247
# district_id =  25
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  5343
# district_id =  64
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  5129
# district_id =  68
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3713
# district_id =  14
# date =  1993-06-08
# frequency  =  POPLATEK TYDNE
#
# account_id =  2327
# district_id =  19
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  774
# district_id =  1
# date =  1993-06-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1990
# district_id =  1
# date =  1993-06-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2388
# district_id =  30
# date =  1993-06-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  3566
# district_id =  21
# date =  1993-06-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  10266
# district_id =  54
# date =  1993-06-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  3771
# district_id =  22
# date =  1993-06-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1978
# district_id =  57
# date =  1993-06-11
# frequency  =  POPLATEK TYDNE
#
# account_id =  2022
# district_id =  72
# date =  1993-06-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  3542
# district_id =  49
# date =  1993-06-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1515
# district_id =  11
# date =  1993-06-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  4171
# district_id =  28
# date =  1993-06-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  433
# district_id =  20
# date =  1993-06-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  1373
# district_id =  47
# date =  1993-06-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  3246
# district_id =  54
# date =  1993-06-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  1475
# district_id =  1
# date =  1993-06-14
# frequency  =  POPLATEK TYDNE
#
# account_id =  3133
# district_id =  66
# date =  1993-06-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2779
# district_id =  73
# date =  1993-06-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  135
# district_id =  75
# date =  1993-06-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  446
# district_id =  50
# date =  1993-06-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  9093
# district_id =  47
# date =  1993-06-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  432
# district_id =  46
# date =  1993-06-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  2880
# district_id =  71
# date =  1993-06-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  5767
# district_id =  72
# date =  1993-06-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  1998
# district_id =  1
# date =  1993-06-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  2554
# district_id =  36
# date =  1993-06-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2933
# district_id =  10
# date =  1993-06-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  773
# district_id =  15
# date =  1993-06-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  4894
# district_id =  14
# date =  1993-06-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3969
# district_id =  39
# date =  1993-06-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  1277
# district_id =  31
# date =  1993-06-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  5120
# district_id =  1
# date =  1993-06-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  738
# district_id =  34
# date =  1993-06-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1299
# district_id =  1
# date =  1993-06-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  148
# district_id =  8
# date =  1993-06-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  899
# district_id =  72
# date =  1993-06-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  3521
# district_id =  75
# date =  1993-06-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  3786
# district_id =  21
# date =  1993-06-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  886
# district_id =  1
# date =  1993-06-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  5228
# district_id =  77
# date =  1993-06-23
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  702
# district_id =  12
# date =  1993-06-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  300
# district_id =  1
# date =  1993-06-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1451
# district_id =  64
# date =  1993-06-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  2940
# district_id =  54
# date =  1993-06-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  1837
# district_id =  23
# ...
# district_id =  1
# date =  1997-10-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1342
# district_id =  9
# date =  1997-10-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  121
# district_id =  55
# date =  1997-10-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  1727
# district_id =  9
# date =  1997-10-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  2097
# district_id =  46
# date =  1997-10-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  133
# district_id =  64
# date =  1997-10-11
# frequency  =  POPLATEK TYDNE
#
# account_id =  2897
# district_id =  51
# date =  1997-10-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  5708
# district_id =  64
# date =  1997-10-12
# frequency  =  POPLATEK TYDNE
#
# account_id =  7049
# district_id =  69
# date =  1997-10-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  1279
# district_id =  28
# date =  1997-10-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  502
# district_id =  1
# date =  1997-10-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  1506
# district_id =  51
# date =  1997-10-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  2231
# district_id =  2
# date =  1997-10-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  966
# district_id =  15
# date =  1997-10-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  1968
# district_id =  16
# date =  1997-10-14
# frequency  =  POPLATEK TYDNE
#
# account_id =  2879
# district_id =  15
# date =  1997-10-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  3023
# district_id =  35
# date =  1997-10-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  3561
# district_id =  33
# date =  1997-10-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  1807
# district_id =  21
# date =  1997-10-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  11327
# district_id =  7
# date =  1997-10-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  2053
# district_id =  5
# date =  1997-10-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  550
# district_id =  24
# date =  1997-10-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  3324
# district_id =  3
# date =  1997-10-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  1061
# district_id =  44
# date =  1997-10-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  2215
# district_id =  48
# date =  1997-10-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  961
# district_id =  1
# date =  1997-10-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2579
# district_id =  24
# date =  1997-10-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  3919
# district_id =  34
# date =  1997-10-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  3875
# district_id =  44
# date =  1997-10-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2311
# district_id =  28
# date =  1997-10-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  2556
# district_id =  46
# date =  1997-10-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1615
# district_id =  1
# date =  1997-10-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  2910
# district_id =  68
# date =  1997-10-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  2756
# district_id =  24
# date =  1997-10-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1572
# district_id =  72
# date =  1997-10-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  3857
# district_id =  54
# date =  1997-10-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  156
# district_id =  64
# date =  1997-10-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  3922
# district_id =  68
# date =  1997-10-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  1209
# district_id =  23
# date =  1997-10-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  2371
# district_id =  15
# date =  1997-10-23
# frequency  =  POPLATEK TYDNE
#
# account_id =  852
# district_id =  57
# date =  1997-10-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  2152
# district_id =  22
# date =  1997-10-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  398
# district_id =  69
# date =  1997-10-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  2174
# district_id =  18
# date =  1997-10-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  3705
# district_id =  20
# date =  1997-10-24
# frequency  =  POPLATEK MESICNE
#
# account_id =  1172
# district_id =  6
# date =  1997-10-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  876
# district_id =  4
# date =  1997-10-26
# frequency  =  POPLATEK MESICNE
#
# account_id =  2413
# district_id =  33
# date =  1997-10-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3963
# district_id =  9
# date =  1997-10-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  643
# district_id =  64
# date =  1997-10-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  1340
# district_id =  52
# date =  1997-10-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  2703
# district_id =  61
# date =  1997-10-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  671
# district_id =  60
# date =  1997-10-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  782
# district_id =  42
# date =  1997-10-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  2784
# district_id =  40
# date =  1997-10-30
# frequency  =  POPLATEK MESICNE
#
# account_id =  1703
# district_id =  72
# date =  1997-11-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  3598
# district_id =  76
# date =  1997-11-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  639
# district_id =  1
# date =  1997-11-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  3325
# district_id =  11
# date =  1997-11-03
# frequency  =  POPLATEK MESICNE
#
# account_id =  10613
# district_id =  55
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  606
# district_id =  75
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  9227
# district_id =  51
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  1723
# district_id =  70
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  3404
# district_id =  33
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  1657
# district_id =  12
# date =  1997-11-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  3395
# district_id =  16
# date =  1997-11-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  2296
# district_id =  29
# date =  1997-11-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  644
# district_id =  4
# date =  1997-11-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2402
# district_id =  18
# date =  1997-11-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  2391
# district_id =  2
# date =  1997-11-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  1140
# district_id =  49
# date =  1997-11-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  952
# district_id =  41
# date =  1997-11-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  696
# district_id =  54
# date =  1997-11-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  2998
# district_id =  21
# date =  1997-11-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  867
# district_id =  60
# date =  1997-11-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1208
# district_id =  4
# date =  1997-11-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  3423
# district_id =  11
# date =  1997-11-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2831
# district_id =  1
# date =  1997-11-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2211
# district_id =  61
# date =  1997-11-10
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  3360
# district_id =  71
# date =  1997-11-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1245
# district_id =  68
# date =  1997-11-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  1348
# district_id =  55
# date =  1997-11-12
# frequency  =  POPLATEK MESICNE
#
# account_id =  2920
# district_id =  73
# date =  1997-11-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  566
# district_id =  8
# date =  1997-11-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  2658
# district_id =  27
# date =  1997-11-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  2721
# district_id =  74
# date =  1997-11-14
# frequency  =  POPLATEK MESICNE
#
# account_id =  1833
# district_id =  54
# date =  1997-11-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  2221
# district_id =  58
# date =  1997-11-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  149
# district_id =  43
# date =  1997-11-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3082
# district_id =  33
# date =  1997-11-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3156
# district_id =  1
# date =  1997-11-16
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  2438
# district_id =  71
# date =  1997-11-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  2693
# district_id =  17
# date =  1997-11-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  1866
# district_id =  4
# date =  1997-11-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  3365
# district_id =  11
# date =  1997-11-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  3382
# district_id =  23
# date =  1997-11-20
# frequency  =  POPLATEK TYDNE
#
# account_id =  2125
# district_id =  43
# date =  1997-11-20
# frequency  =  POPLATEK TYDNE
#
# account_id =  3396
# district_id =  1
# date =  1997-11-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3105
# district_id =  37
# date =  1997-11-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  2162
# district_id =  50
# date =  1997-11-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1125
# district_id =  1
# date =  1997-11-21
# frequency  =  POPLATEK TYDNE
#
# account_id =  2979
# district_id =  10
# date =  1997-11-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2850
# district_id =  57
# date =  1997-11-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  2832
# district_id =  12
# date =  1997-11-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  3102
# district_id =  33
# date =  1997-11-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  295
# district_id =  66
# date =  1997-11-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1523
# district_id =  52
# date =  1997-11-24
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  215
# district_id =  31
# date =  1997-11-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  421
# district_id =  75
# date =  1997-11-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3715
# district_id =  74
# date =  1997-11-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  934
# district_id =  9
# date =  1997-11-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  3333
# district_id =  44
# date =  1997-11-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  1798
# district_id =  46
# date =  1997-11-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  10005
# district_id =  64
# date =  1997-11-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  4386
# district_id =  51
# date =  1997-11-29
# frequency  =  POPLATEK TYDNE
#
# account_id =  1868
# district_id =  16
# date =  1997-11-29
# frequency  =  POPLATEK TYDNE
#
# account_id =  232
# district_id =  45
# date =  1997-11-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  298
# district_id =  35
# date =  1997-12-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1717
# district_id =  67
# date =  1997-12-02
# frequency  =  POPLATEK MESICNE
#
# account_id =  1960
# district_id =  31
# date =  1997-12-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  1049
# district_id =  18
# date =  1997-12-04
# frequency  =  POPLATEK MESICNE
#
# account_id =  2918
# district_id =  15
# date =  1997-12-05
# frequency  =  POPLATEK PO OBRATU
#
# account_id =  4140
# district_id =  28
# date =  1997-12-05
# frequency  =  POPLATEK MESICNE
#
# account_id =  21
# district_id =  54
# date =  1997-12-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  1650
# district_id =  39
# date =  1997-12-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  800
# district_id =  11
# date =  1997-12-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  3415
# district_id =  75
# date =  1997-12-06
# frequency  =  POPLATEK MESICNE
#
# account_id =  3722
# district_id =  76
# date =  1997-12-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  736
# district_id =  75
# date =  1997-12-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  2787
# district_id =  1
# date =  1997-12-07
# frequency  =  POPLATEK MESICNE
#
# account_id =  673
# district_id =  31
# date =  1997-12-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  3406
# district_id =  53
# date =  1997-12-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  2796
# district_id =  5
# date =  1997-12-08
# frequency  =  POPLATEK TYDNE
#
# account_id =  2775
# district_id =  30
# date =  1997-12-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  276
# district_id =  38
# date =  1997-12-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  315
# district_id =  45
# date =  1997-12-08
# frequency  =  POPLATEK MESICNE
#
# account_id =  1072
# district_id =  65
# date =  1997-12-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  1156
# district_id =  59
# date =  1997-12-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  3836
# district_id =  68
# date =  1997-12-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  3013
# district_id =  73
# date =  1997-12-09
# frequency  =  POPLATEK MESICNE
#
# account_id =  3033
# district_id =  69
# date =  1997-12-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  3174
# district_id =  65
# date =  1997-12-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  134
# district_id =  34
# date =  1997-12-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  1229
# district_id =  46
# date =  1997-12-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  3209
# district_id =  45
# date =  1997-12-10
# frequency  =  POPLATEK MESICNE
#
# account_id =  2820
# district_id =  36
# date =  1997-12-11
# frequency  =  POPLATEK MESICNE
#
# account_id =  938
# district_id =  70
# date =  1997-12-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  3501
# district_id =  36
# date =  1997-12-13
# frequency  =  POPLATEK MESICNE
#
# account_id =  3616
# district_id =  50
# date =  1997-12-15
# frequency  =  POPLATEK MESICNE
#
# account_id =  3911
# district_id =  32
# date =  1997-12-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  3992
# district_id =  43
# date =  1997-12-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  579
# district_id =  1
# date =  1997-12-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  2892
# district_id =  64
# date =  1997-12-16
# frequency  =  POPLATEK MESICNE
#
# account_id =  1186
# district_id =  64
# date =  1997-12-17
# frequency  =  POPLATEK MESICNE
#
# account_id =  2440
# district_id =  19
# date =  1997-12-18
# frequency  =  POPLATEK MESICNE
#
# account_id =  2791
# district_id =  25
# date =  1997-12-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  3169
# district_id =  19
# date =  1997-12-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  2049
# district_id =  67
# date =  1997-12-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  758
# district_id =  51
# date =  1997-12-19
# frequency  =  POPLATEK MESICNE
#
# account_id =  1177
# district_id =  27
# date =  1997-12-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  246
# district_id =  65
# date =  1997-12-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  1171
# district_id =  18
# date =  1997-12-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3187
# district_id =  59
# date =  1997-12-20
# frequency  =  POPLATEK MESICNE
#
# account_id =  3385
# district_id =  1
# date =  1997-12-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  703
# district_id =  54
# date =  1997-12-21
# frequency  =  POPLATEK MESICNE
#
# account_id =  1318
# district_id =  56
# date =  1997-12-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  889
# district_id =  43
# date =  1997-12-22
# frequency  =  POPLATEK MESICNE
#
# account_id =  4332
# district_id =  74
# date =  1997-12-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  564
# district_id =  5
# date =  1997-12-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  3934
# district_id =  6
# date =  1997-12-23
# frequency  =  POPLATEK MESICNE
#
# account_id =  1983
# district_id =  54
# date =  1997-12-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  727
# district_id =  35
# date =  1997-12-25
# frequency  =  POPLATEK MESICNE
#
# account_id =  3048
# district_id =  74
# date =  1997-12-26
# frequency  =  POPLATEK TYDNE
#
# account_id =  3025
# district_id =  25
# date =  1997-12-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  906
# district_id =  59
# date =  1997-12-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  845
# district_id =  14
# date =  1997-12-27
# frequency  =  POPLATEK MESICNE
#
# account_id =  124
# district_id =  55
# date =  1997-12-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  3958
# district_id =  59
# date =  1997-12-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  777
# district_id =  30
# date =  1997-12-28
# frequency  =  POPLATEK MESICNE
#
# account_id =  1573
# district_id =  63
# date =  1997-12-29
# frequency  =  POPLATEK MESICNE
#
# account_id =  3276
# district_id =  1
# date =  1997-12-29
# frequency  =  POPLATEK MESICNE
